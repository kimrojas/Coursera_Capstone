# %% [markdown]
# # Battle of Neighborhoods

# %% [markdown]
# ---
# ## I. Introduction
#
# Philippines is one of the south east asian countries with a growing economy. As it might be a good option for a prospective business, it is invaluable to distinguish whether a business may be successful by analyzing trends and land potential. Considering that establishing a business is anything but risk-free, this land and trend analysis can help lower these risk by recommending the best spots and business field/industry to investors.

# %% [markdown]
# ---
# ## II. Data
#
# There are 3 general sets of data, taken from different sources.
#
# A. City, District, Area, and Population data [LINK](https://www.citypopulation.de/en/philippines/)
# B. Geolocation (latitude, longitude) from geopy api
# C. Nearby store information from four square api
#
# In this project, we considered five of the most developed cities in the Philippines.

# %% [markdown]
# ---
# ## III. Methodology
#
# A. Data Preparation
# In this section, we prepare the dataframe to be use for the modelling. The summary of the flow is:
# - Webscrape the data from city info webpage
#   - webpage retrieval and parsing via requests and BeautifulSoup
# - Query the geolocation data of each district
#   - A multi-try connection was implemented for times when geolocation query fails
# - Combine webscraped data and geolocation into a concise dataset
#   - Join using Pandas untilities
#
# B. Data Processing
#
# - Customer assurance filter
#     * Since the analysis will be used for a prospective business location, it needs to consider that there are ample customer and foot traffic around the spot. To assure this, I have enforce a population limit of at least 5000 people and a population density limit of 2000 people / km^2. These numbers are a good estimate for a metropolitan and commercial district. The filtered dataset will have significantly lower count as
#
# C. Data Analysis

# %% [markdown]
# ### A. Data Preparation

# %% [markdown]
# #### A.1. Import the necessary libraries

# %%
# For webscraping 
from bs4 import BeautifulSoup as bs
import requests

# For Data manipulation
import pandas as pd
import numpy as np


# For Lon Lat, but not used
from geopy.geocoders import Nominatim

# For cool visual
from tqdm.notebook import tqdm

# For map
import folium

# For identity
import keys

# For lon lat request
import googlemaps

# For clustering
from sklearn.cluster import KMeans

# For graph and folium colors
import matplotlib.pyplot  as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

# For the bar graphs
import seaborn as sns

# For saving folium map to png
import io
from PIL import Image
from selenium import webdriver

# %% [markdown]
# #### A.2. Webscrape, query, and filter
#
# I created a function that will:
# 1. Extract and filter the data from the webpage.
# 2. Query the location data (longitude and latitude)
# 3. Population limiter
#
# Herein, I used the google api because nominatim is slow and sometimes give bad location results.

# %%
def extract_data(label, url, pop_limit=0, den_limit=0, debug=False): 
    # Request  and parse html webpage
    html=requests.get(url).text
    soup = bs(html, 'html.parser')
    data = soup.find_all('td')[:-6] # filter only necessary lines
    
    table_contents=[]
    for i in tqdm(range(0, len(data), 6), desc=label): # iterate over each entry, each entry has 6 lines      
        # Data extracted from webpage
        cell={}
#         cell['City'] = (data[i].get('data-wiki').split(',')[-1]).replace(' City', '')
#         cell['District'] = str(data[i].span.text)

        a1 = (data[i].get('data-wiki').split(',')[-1])
        a2 = str(data[i].span.text)
        
        cell['Address'] = "{}, {} City".format(a2, a1) 
        cell['Population'] = int((data[i+4].text).replace(',', ''))
        cell['Area'] = float(data[i].get('data-area'))
        cell['Density'] = float(data[i].get('data-density'))
        
        # Population filter
        if cell['Population'] < pop_limit: continue
        if cell['Density'] < pop_limit: continue
        
        # Query longitude and latitude for each district
        address = "Baranggay {}, {}".format(cell['Address'], "PH")
        if debug: print(address) #debugging purposes only
        
        # Multi-try connection (assures connection)
        tries = 5
        for trial in range(tries+1):
            try:
#                 gmaps_client = googlemaps.Client(keys.google_map)
#                 geocode_result = gmaps_client.geocode(address)
#                 result = geocode_result[0]
                geolocator = Nominatim(user_agent="foursquare_agent")
                geocode_result = geolocator.geocode(address)
                result = geocode_result[0]
                break
            except:
                pass
        latitude =  float(result['geometry']['location']['lat'])
        longitude = float(result['geometry']['location']['lng'])
        
        cell['Latitude'] = latitude
        cell['Longitude'] = longitude
        
        table_contents.append(cell)
    
    # Create final dataframe
    df = pd.DataFrame(table_contents)
    
    return df

# %% [markdown]
# **Activate the functions to extract data**

# %%
makati_dat = extract_data('Makati', 'https://www.citypopulation.de/en/philippines/makati/', pop_limit=10000, den_limit=4000)
taguig_dat = extract_data('Taguig', 'https://www.citypopulation.de/en/philippines/taguig/', pop_limit=10000, den_limit=4000)
muntinlupa_dat = extract_data('Muntinlupa', 'https://www.citypopulation.de/en/philippines/muntinlupa/', pop_limit=10000, den_limit=4000)

print(makati_dat.shape, taguig_dat.shape, muntinlupa_dat.shape)
# Out:
# Makati:   0%|          | 0/33 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6ec595d67a02> in <module>
# ----> 1 makati_dat = extract_data('Makati', 'https://www.citypopulation.de/en/philippines/makati/', pop_limit=10000, den_limit=4000)
#       2 taguig_dat = extract_data('Taguig', 'https://www.citypopulation.de/en/philippines/taguig/', pop_limit=10000, den_limit=4000)
#       3 muntinlupa_dat = extract_data('Muntinlupa', 'https://www.citypopulation.de/en/philippines/muntinlupa/', pop_limit=10000, den_limit=4000)
#       4
#       5 print(makati_dat.shape, taguig_dat.shape, muntinlupa_dat.shape)
#
# <ipython-input-4-7b2c44cfe85c> in extract_data(label, url, pop_limit, den_limit, debug)
#      41             except:
#      42                 pass
# ---> 43         latitude =  float(result['geometry']['location']['lat'])
#      44         longitude = float(result['geometry']['location']['lng'])
#      45
#
# NameError: name 'result' is not defined

# %% [markdown]
# #### A.3. Combine datasets into a single main dataset

# %%
main_data = pd.concat([taguig_dat, makati_dat, muntinlupa_dat], ignore_index=True)
main_data.sample(5)
# Out:
#                       Address  Population    Area     Density   Latitude  \
# 39      Tejeros,  Makati City       13696  0.2848  48089.8876  14.571537
# 5   Ibayo-Tipas,  Taguig City       20932  0.8777  23850.0541  14.538856
# 42  Bayanan,  Muntinlupa City       36673  0.9162  40026.8497  14.408534
# 19         Wawa,  Taguig City       11177  1.0266  10887.7135  14.520191
# 46    Sucat,  Muntinlupa City       57504  2.6645  21581.2110  14.454611
#
#      Longitude
# 39  121.014157
# 5   121.087251
# 42  121.046410
# 19  121.077938
# 46  121.049277

# %% [markdown]
# #### A.4. Map visualization
#
# **Let us visualize the map.**
#
# Find the center of the map.

# %%
def map_center():
    global main_data
    Lat = main_data['Latitude'].min() + (main_data['Latitude'].max() - main_data['Latitude'].min())/2
    Lon = main_data['Longitude'].min()+ (main_data['Longitude'].max() - main_data['Longitude'].min())/2
    return [Lat, Lon]

visual_center = map_center()
print (visual_center)
# Out:
# [14.4785963, 121.0453278]

# %% [markdown]
# Now, let's visualize the map along with its respective neighborhoods.

# %%
def visual_city(city_data):
    global visual_center
    global main_data
    latitude, longitude = visual_center[0], visual_center[1]
    map = folium.Map(location=[latitude, longitude], zoom_start=12)
    
    for lat, lng, neighborhood in zip(main_data['Latitude'], main_data['Longitude'], main_data['Address']):
        label = '{}'.format(neighborhood)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map)
        
    return map

# %%
visual_city([taguig_dat, makati_dat, muntinlupa_dat])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_724b6813e21c4b81a46c18776e3698c4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_724b6813e21c4b81a46c18776e3698c4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_724b6813e21c4b81a46c18776e3698c4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_724b6813e21c4b81a46c18776e3698c4%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B14.4785963%2C121.0453278%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# #### A.5. Exploring the neighborhood
#
# First, prepare my Foursquare credentials. (*Note: The credential details are stored and protected in an alternate python file.*)

# %%
CLIENT_ID = keys.CLIENT_ID
CLIENT_SECRET = keys.CLIENT_SECRET 
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %% [markdown]
# **Request and Process**

# %% [markdown]
# Creating a function GET requests and data-processing

# %%
def getNearbyVenues(address, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for address, lat, lng in tqdm(zip(address, latitudes, longitudes), total=len(address)):
#         print(city, district)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            address, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Address', 
                  'Address Latitude', 
                  'Address Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
main_venues = getNearbyVenues(main_data.Address, main_data.Latitude, main_data.Longitude)
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]

# %%
print("The size of the dataset is {}.".format(main_venues.shape))
main_venues.sample(3)
# Out:
# The size of the dataset is (936, 7).
#                        Address  Address Latitude  Address Longitude  \
# 885  Bayanan,  Muntinlupa City         14.408534         121.046410
# 395      Olympia,  Makati City         14.571781         121.021325
# 2     Bagumbayan,  Taguig City         14.477028         121.055009
#
#                                     Venue  Venue Latitude  Venue Longitude  \
# 885     Amber Golden Chain of Restaurants       14.405299       121.046876
# 395  The Burgery - The Bad Boys of Burger       14.575601       121.019862
# 2                       The Mahogany Park       14.479082       121.058063
#
#        Venue Category
# 885  Asian Restaurant
# 395      Burger Joint
# 2                Park

# %%
main_venues.groupby('Address').count()
# Out:
#                                       Address Latitude  Address Longitude  \
# Address
# Alabang,  Muntinlupa City                           46                 46
# Bagumbayan,  Taguig City                             3                  3
# Bambang,  Taguig City                               12                 12
# Bangkal,  Makati City                               21                 21
# Bayanan,  Muntinlupa City                           21                 21
# Bel-Air,  Makati City                               83                 83
# Calzada,  Taguig City                                4                  4
# Cembo,  Makati City                                 15                 15
# Central Signal Village,  Taguig City                 7                  7
# Comembo,  Makati City                               23                 23
# Cupang,  Muntinlupa City                            10                 10
# East Rembo,  Makati City                             4                  4
# Guadalupe Nuevo,  Makati City                       20                 20
# Guadalupe Viejo,  Makati City                       40                 40
# Ibayo-Tipas,  Taguig City                            1                  1
# Katuparan,  Taguig City                              4                  4
# Lower Bicutan,  Taguig City                          4                  4
# Maharlika Village,  Taguig City                      4                  4
# New Lower Bicutan,  Taguig City                      1                  1
# North Daang Hari,  Taguig City                      51                 51
# North Signal Village,  Taguig City                  13                 13
# Olympia,  Makati City                               49                 49
# Palanan,  Makati City                               22                 22
# Pembo,  Makati City                                 49                 49
# Pinagsama,  Taguig City                              6                  6
# Pio Del Pilar,  Makati City                         74                 74
# Pitogo,  Makati City                                56                 56
# Poblacion,  Makati City                            100                100
# Poblacion,  Muntinlupa City                          4                  4
# Post Proper Northside,  Makati City                 13                 13
# Post Proper Southside,  Makati City                 10                 10
# Putatan,  Muntinlupa City                            4                  4
# Rizal,  Makati City                                  4                  4
# San Antonio,  Makati City                           49                 49
# South Cembo,  Makati City                           15                 15
# South Daang Hari,  Taguig City                       4                  4
# South Signal Village,  Taguig City                   6                  6
# Sucat,  Muntinlupa City                             13                 13
# Tanyag,  Taguig City                                 1                  1
# Tejeros,  Makati City                               14                 14
# Tuktukan,  Taguig City                              22                 22
# Upper Bicutan,  Taguig City                          5                  5
# Ususan,  Taguig City                                 9                  9
# West Rembo,  Makati City                            20                 20
#
#                                       Venue  Venue Latitude  Venue Longitude  \
# Address
# Alabang,  Muntinlupa City                46              46               46
# Bagumbayan,  Taguig City                  3               3                3
# Bambang,  Taguig City                    12              12               12
# Bangkal,  Makati City                    21              21               21
# Bayanan,  Muntinlupa City                21              21               21
# Bel-Air,  Makati City                    83              83               83
# Calzada,  Taguig City                     4               4                4
# Cembo,  Makati City                      15              15               15
# Central Signal Village,  Taguig City      7               7                7
# Comembo,  Makati City                    23              23               23
# Cupang,  Muntinlupa City                 10              10               10
# East Rembo,  Makati City                  4               4                4
# Guadalupe Nuevo,  Makati City            20              20               20
# Guadalupe Viejo,  Makati City            40              40               40
# Ibayo-Tipas,  Taguig City                 1               1                1
# Katuparan,  Taguig City                   4               4                4
# Lower Bicutan,  Taguig City               4               4                4
# Maharlika Village,  Taguig City           4               4                4
# New Lower Bicutan,  Taguig City           1               1                1
# North Daang Hari,  Taguig City           51              51               51
# North Signal Village,  Taguig City       13              13               13
# Olympia,  Makati City                    49              49               49
# Palanan,  Makati City                    22              22               22
# Pembo,  Makati City                      49              49               49
# Pinagsama,  Taguig City                   6               6                6
# Pio Del Pilar,  Makati City              74              74               74
# Pitogo,  Makati City                     56              56               56
# Poblacion,  Makati City                 100             100              100
# Poblacion,  Muntinlupa City               4               4                4
# Post Proper Northside,  Makati City      13              13               13
# Post Proper Southside,  Makati City      10              10               10
# Putatan,  Muntinlupa City                 4               4                4
# Rizal,  Makati City                       4               4                4
# San Antonio,  Makati City                49              49               49
# South Cembo,  Makati City                15              15               15
# South Daang Hari,  Taguig City            4               4                4
# South Signal Village,  Taguig City        6               6                6
# Sucat,  Muntinlupa City                  13              13               13
# Tanyag,  Taguig City                      1               1                1
# Tejeros,  Makati City                    14              14               14
# Tuktukan,  Taguig City                   22              22               22
# Upper Bicutan,  Taguig City               5               5                5
# Ususan,  Taguig City                      9               9                9
# West Rembo,  Makati City                 20              20               20
#
#                                       Venue Category
# Address
# Alabang,  Muntinlupa City                         46
# Bagumbayan,  Taguig City                           3
# Bambang,  Taguig City                             12
# Bangkal,  Makati City                             21
# Bayanan,  Muntinlupa City                         21
# Bel-Air,  Makati City                             83
# Calzada,  Taguig City                              4
# Cembo,  Makati City                               15
# Central Signal Village,  Taguig City               7
# Comembo,  Makati City                             23
# Cupang,  Muntinlupa City                          10
# East Rembo,  Makati City                           4
# Guadalupe Nuevo,  Makati City                     20
# Guadalupe Viejo,  Makati City                     40
# Ibayo-Tipas,  Taguig City                          1
# Katuparan,  Taguig City                            4
# Lower Bicutan,  Taguig City                        4
# Maharlika Village,  Taguig City                    4
# New Lower Bicutan,  Taguig City                    1
# North Daang Hari,  Taguig City                    51
# North Signal Village,  Taguig City                13
# Olympia,  Makati City                             49
# Palanan,  Makati City                             22
# Pembo,  Makati City                               49
# Pinagsama,  Taguig City                            6
# Pio Del Pilar,  Makati City                       74
# Pitogo,  Makati City                              56
# Poblacion,  Makati City                          100
# Poblacion,  Muntinlupa City                        4
# Post Proper Northside,  Makati City               13
# Post Proper Southside,  Makati City               10
# Putatan,  Muntinlupa City                          4
# Rizal,  Makati City                                4
# San Antonio,  Makati City                         49
# South Cembo,  Makati City                         15
# South Daang Hari,  Taguig City                     4
# South Signal Village,  Taguig City                 6
# Sucat,  Muntinlupa City                           13
# Tanyag,  Taguig City                               1
# Tejeros,  Makati City                             14
# Tuktukan,  Taguig City                            22
# Upper Bicutan,  Taguig City                        5
# Ususan,  Taguig City                               9
# West Rembo,  Makati City                          20

# %% [markdown]
# This marks the end of the data preparation.
#
#
# ### B. Analysis

# %% [markdown]
# #### B.1. Re-classification
# First, let us examine the number of categories in our dataset.

# %%
print('There are {} uniques categories.'.format(len(main_venues['Venue Category'].unique())))
# Out:
# There are 183 uniques categories.

# %% [markdown]
# The number of unique categories is actually quite problematic due to similarities between some elements. For example, Coffee place is labeled separately from Cafe. To fix this problem, we can re-classify these venue categories into a few general classifications. In this work, the classifications utilized are Food, Leisure, Health, Housing, and Essential Service.
#
# Additionally, the needless increase in dimensionality (due to one-hot encoding with overly large variation), further complicates and reduces the amount of information that can be derived from the clustering results.

# %%
main_venues.head()
# Out:
#                     Address  Address Latitude  Address Longitude  \
# 0  Bagumbayan,  Taguig City         14.477028         121.055009
# 1  Bagumbayan,  Taguig City         14.477028         121.055009
# 2  Bagumbayan,  Taguig City         14.477028         121.055009
# 3     Bambang,  Taguig City         14.555414         121.080087
# 4     Bambang,  Taguig City         14.555414         121.080087
#
#                                  Venue  Venue Latitude  Venue Longitude  \
# 0                  Our Residence's Gym       14.477310       121.054441
# 1  Mahogany Homes, Taguig Tennis Court       14.479082       121.058063
# 2                    The Mahogany Park       14.479082       121.058063
# 3                 Tanghalang Pasigueño       14.559338       121.082194
# 4                     D'Original Pares       14.555842       121.075907
#
#          Venue Category
# 0  Gym / Fitness Center
# 1          Tennis Court
# 2                  Park
# 3               Theater
# 4          Noodle House

# %%
def key_search(key_list, mystring):
    for x in key_list:
        if x.lower() in mystring.lower():
            return True
    return False

# Function to classify based on keywords
def classify(list):
    data_class = []
    for i in list:
        #classifier
        if key_search(['Food', 'Restaurant', 'Diner', 'Chicken', "Burger", "Taco", 'Salad', 'Sandwich', 'Tea', 'Coffee', 'Donut',
                      'Ice Cream', 'Dessert', 'Bakery', 'BBQ', 'Café', 'Breakfast', 'Buffet', "Noodle", "Deli", "Yogurt", "Burrito",
                      "Creperie", "Soup", "Snack", 'Bistro', 'Pastry', "Cupcake", 'Bagel', 'Wings Joint', 'Gourmet', "Pizza"], i):
            data_class.append("Food")
            continue
        if key_search(['Bar', 'Pub', 'Park',  'Court', 'Theater','Track', 'Spa', 'Bowling', 'Lounge', 'Entertainment',
                      'Club', 'Garden', "Miscellaneous Shop", "Field", 'Arcade', 'Gun Range', "Plaza", "Music Venue",
                      "Scenic Lookout", 'Pool', 'Gallery', 'Soccer', 'Resort','Athletics & Sports', 'Spiritual Center','Roof Deck',
                      'Speakeasy', 'Dance Studio'], i):
            data_class.append("Liesure")
            continue
        if key_search(['Cloth', "Grocery","Furniture", "Market", "Mall", 'Store', 'Rest Area', "Automotive", "Mobile Phone", 'Bike',
                      "Shopping", "Recreation", "Sporting Goods", 'Boutique', 'Cosmetics', 'Gas Station'  ], i):
            data_class.append("Retail")
            continue
        if key_search(['Pharmacy', 'Veterinarian', "Pet Service", 'Health & Beauty Service', 'Massage Studio', 'Yoga Studio','Gym'], i):
            data_class.append("Health")
            continue
        if key_search(['Bus', 'Airport', 'Transport', 'Toll', 'Road', 'Tunnel', 'Farm', 'Intersection', 'Train Station', 'Cemetery'], i):
            data_class.append("Essential Service")
            continue
        if key_search(['Housing', 'Multiplex', 'Motel', 'Hostel','Hotel'], i):
            data_class.append("Housing")
            continue              
    return data_class

# %%
main_venues['Venue Category'] = classify(main_venues["Venue Category"])

# %%
print('There are {} uniques categories.'.format(len(main_venues['Venue Category'].unique())))
# Out:
# There are 6 uniques categories.

# %% [markdown]
# With this, the categories are now fixed.

# %% [markdown]
# #### B.2. One-hot encoding
# Next, we pre-process the data to a format that can be used.

# %%
# one hot encoding
main_onehot = pd.get_dummies(main_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
main_onehot['Address'] = main_venues['Address'] 

# move neighborhood column to the first column
fixed_columns = [main_onehot.columns[-1]] + list(main_onehot.columns[:-1])
main_onehot = main_onehot[fixed_columns]

print(main_onehot.shape)
main_onehot.sample(3)
# Out:
# (936, 7)
#                                 Address  Essential Service  Food  Health  \
# 613             Poblacion,  Makati City                  0     1       0
# 79       North Daang Hari,  Taguig City                  1     0       0
# 103  North Signal Village,  Taguig City                  0     1       0
#
#      Housing  Liesure  Retail
# 613        0        0       0
# 79         0        0       0
# 103        0        0       0

# %% [markdown]
# #### B.3. Frequency of occurence
# Let's group rows by address (with sorting mechanism) and by taking the mean of the frequency of occurrence of each category

# %%
main_grouped = main_onehot.groupby('Address').mean().reset_index()
main_grouped.head(10)
# Out:
#                                 Address  Essential Service      Food  \
# 0             Alabang,  Muntinlupa City           0.000000  0.521739
# 1              Bagumbayan,  Taguig City           0.000000  0.000000
# 2                 Bambang,  Taguig City           0.000000  0.583333
# 3                 Bangkal,  Makati City           0.000000  0.523810
# 4             Bayanan,  Muntinlupa City           0.047619  0.571429
# 5                 Bel-Air,  Makati City           0.000000  0.698795
# 6                 Calzada,  Taguig City           0.000000  0.750000
# 7                   Cembo,  Makati City           0.000000  0.400000
# 8  Central Signal Village,  Taguig City           0.000000  0.857143
# 9                 Comembo,  Makati City           0.000000  0.565217
#
#      Health   Housing   Liesure    Retail
# 0  0.021739  0.021739  0.260870  0.173913
# 1  0.333333  0.000000  0.666667  0.000000
# 2  0.000000  0.000000  0.083333  0.333333
# 3  0.095238  0.000000  0.142857  0.238095
# 4  0.047619  0.000000  0.095238  0.238095
# 5  0.024096  0.048193  0.132530  0.096386
# 6  0.000000  0.000000  0.000000  0.250000
# 7  0.000000  0.066667  0.200000  0.333333
# 8  0.000000  0.000000  0.000000  0.142857
# 9  0.173913  0.000000  0.086957  0.173913

# %% [markdown]
# Let's confirm the new size

# %%
main_grouped.shape
# Out:
# (44, 7)

# %% [markdown]
# #### B.4. Most common venues
#
# Let's print each neighborhood along with the top 5 most common venues

# %% [markdown]
# **Venue type sorter**

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Address']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Address'] = main_grouped['Address']

for ind in np.arange(main_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(main_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                  Address 1st Most Common Venue  \
# 0              Alabang,  Muntinlupa City                  Food
# 1               Bagumbayan,  Taguig City               Liesure
# 2                  Bambang,  Taguig City                  Food
# 3                  Bangkal,  Makati City                  Food
# 4              Bayanan,  Muntinlupa City                  Food
# 5                  Bel-Air,  Makati City                  Food
# 6                  Calzada,  Taguig City                  Food
# 7                    Cembo,  Makati City                  Food
# 8   Central Signal Village,  Taguig City                  Food
# 9                  Comembo,  Makati City                  Food
# 10              Cupang,  Muntinlupa City                  Food
# 11              East Rembo,  Makati City                  Food
# 12         Guadalupe Nuevo,  Makati City                Retail
# 13         Guadalupe Viejo,  Makati City                  Food
# 14             Ibayo-Tipas,  Taguig City                  Food
# 15               Katuparan,  Taguig City                  Food
# 16           Lower Bicutan,  Taguig City                  Food
# 17       Maharlika Village,  Taguig City               Liesure
# 18       New Lower Bicutan,  Taguig City                Retail
# 19        North Daang Hari,  Taguig City                  Food
# 20    North Signal Village,  Taguig City                  Food
# 21                 Olympia,  Makati City                  Food
# 22                 Palanan,  Makati City                  Food
# 23                   Pembo,  Makati City                  Food
# 24               Pinagsama,  Taguig City                  Food
# 25           Pio Del Pilar,  Makati City                  Food
# 26                  Pitogo,  Makati City                  Food
# 27               Poblacion,  Makati City                  Food
# 28           Poblacion,  Muntinlupa City               Liesure
# 29   Post Proper Northside,  Makati City                  Food
# 30   Post Proper Southside,  Makati City                  Food
# 31             Putatan,  Muntinlupa City                  Food
# 32                   Rizal,  Makati City     Essential Service
# 33             San Antonio,  Makati City                  Food
# 34             South Cembo,  Makati City                  Food
# 35        South Daang Hari,  Taguig City     Essential Service
# 36    South Signal Village,  Taguig City                Retail
# 37               Sucat,  Muntinlupa City                  Food
# 38                  Tanyag,  Taguig City               Liesure
# 39                 Tejeros,  Makati City                  Food
# 40                Tuktukan,  Taguig City                  Food
# 41           Upper Bicutan,  Taguig City                  Food
# 42                  Ususan,  Taguig City                  Food
# 43              West Rembo,  Makati City                  Food
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Liesure                Retail                Health
# 1                 Health     Essential Service                  Food
# 2                 Retail               Liesure     Essential Service
# 3                 Retail               Liesure                Health
# 4                 Retail               Liesure     Essential Service
# 5                Liesure                Retail               Housing
# 6                 Retail     Essential Service                Health
# 7                 Retail               Liesure               Housing
# 8                 Retail     Essential Service                Health
# 9                 Health                Retail               Liesure
# 10                Retail               Housing     Essential Service
# 11                Health     Essential Service               Housing
# 12                  Food               Liesure               Housing
# 13                Retail               Housing               Liesure
# 14     Essential Service                Health               Housing
# 15               Liesure                Retail     Essential Service
# 16                Retail     Essential Service                Health
# 17                Retail     Essential Service                  Food
# 18     Essential Service                  Food                Health
# 19                Retail               Liesure     Essential Service
# 20               Liesure                Retail     Essential Service
# 21               Liesure                Retail                Health
# 22                Health                Retail               Liesure
# 23                Retail               Liesure                Health
# 24               Liesure                Retail     Essential Service
# 25               Liesure                Retail                Health
# 26                Retail               Liesure                Health
# 27               Liesure                Retail               Housing
# 28                  Food                Retail     Essential Service
# 29               Liesure     Essential Service                Health
# 30                Health                Retail     Essential Service
# 31                Retail     Essential Service                Health
# 32                  Food                Health                Retail
# 33               Liesure                Retail               Housing
# 34                Retail               Liesure               Housing
# 35               Liesure                  Food                Health
# 36                  Food               Liesure     Essential Service
# 37               Liesure     Essential Service                Retail
# 38     Essential Service                  Food                Health
# 39                Retail               Housing               Liesure
# 40                Retail     Essential Service                Health
# 41               Liesure                Retail     Essential Service
# 42               Liesure                Retail     Essential Service
# 43               Liesure                Retail     Essential Service
#
#    5th Most Common Venue
# 0                Housing
# 1                Housing
# 2                 Health
# 3      Essential Service
# 4                 Health
# 5                 Health
# 6                Housing
# 7      Essential Service
# 8                Housing
# 9      Essential Service
# 10                Health
# 11               Liesure
# 12     Essential Service
# 13                Health
# 14               Liesure
# 15                Health
# 16               Housing
# 17                Health
# 18               Housing
# 19                Health
# 20                Health
# 21               Housing
# 22     Essential Service
# 23     Essential Service
# 24                Health
# 25               Housing
# 26     Essential Service
# 27     Essential Service
# 28                Health
# 29               Housing
# 30               Liesure
# 31               Housing
# 32               Housing
# 33                Health
# 34     Essential Service
# 35               Housing
# 36                Health
# 37                Health
# 38               Housing
# 39                Health
# 40               Housing
# 41                Health
# 42                Health
# 43                Health

# %% [markdown]
# ### C. Clustering
#
# In this section, we will proceed with the application of clustering.
# Unfortunately, I am not sure what K to use for the K-means clustering.
#
# #### C.1. Clustering function
#
# First, let's create the subroutine function for the k-means clustering with K as an input.

# %%
def clustering(data,kclusters: int):
    data_clustering = data
    kmeans_model = KMeans(n_clusters=kclusters, random_state=0).fit(data_clustering)
    return kmeans_model

# %% [markdown]
# #### C.2. Determine optimal K
#
# Since this is an unsupervised learning, we need to determine first the right number of clusters.
# We do this using the elbow method and the interia of the model.

# %%
k = []
inertia = []

for i in range(2,10):
    data = main_grouped.drop('Address', 1)
    model = clustering(data, i)
    
    k.append(i)
    inertia.append(model.inertia_)

# %% [markdown]
# **Let's try plotting this**

# %%
plt.plot(k, inertia, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.show()

# %% [markdown]
# **From this graph, we can see that the elbow is situated at K = 5. This means that optimal value is K = 5.**
#
# #### C.3. Finalizing the model
#
# Let us now finalize the model using the optimal number of clusters.

# %%
kclusters = 5
data = main_grouped.drop('Address', 1)
final_model = clustering(data, kclusters)

# %% [markdown]
# ---
#
# ## IV. Results

# %%
# add clustering labels
def result():
    result_venues =  neighborhoods_venues_sorted
    main_merged = main_data
    print(final_model.labels_)
    
    try:
        result_venues.insert(0, 'Cluster Labels', final_model.labels_)
    except:
        result_venues['Cluster Labels'] = final_model.labels_

    # merge main_grouped with main_data to add latitude/longitude for each neighborhood
    main_merged_final = main_merged.join(result_venues.set_index('Address'), on='Address')
    main_merged_final = main_merged_final.dropna().reset_index(drop=True)
    main_merged_final['Cluster Labels'] = main_merged_final['Cluster Labels'].astype(int)
    return main_merged_final

# %%
result_data = result()
result_data.head()
# Out:
# [2 4 0 2 0 0 0 2 0 0 0 0 3 0 0 2 0 3 3 0 0 0 0 2 2 0 0 0 2 0 2 0 2 0 2 1 3
#  2 4 2 0 2 2 0]
#                                 Address  Population    Area     Density  \
# 0              Bagumbayan,  Taguig City       40685  2.2602  18000.4601
# 1                 Bambang,  Taguig City       10010  0.4234  23641.9462
# 2                 Calzada,  Taguig City       21747  1.7963  12106.2828
# 3  Central Signal Village,  Taguig City       39674  0.7183  55235.4964
# 4             Ibayo-Tipas,  Taguig City       20932  0.8777  23850.0541
#
#     Latitude   Longitude  Cluster Labels 1st Most Common Venue  \
# 0  14.477028  121.055009               4               Liesure
# 1  14.555414  121.080087               0                  Food
# 2  14.530109  121.080803               0                  Food
# 3  14.510621  121.055009               0                  Food
# 4  14.538856  121.087251               0                  Food
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Health     Essential Service                  Food
# 1                Retail               Liesure     Essential Service
# 2                Retail     Essential Service                Health
# 3                Retail     Essential Service                Health
# 4     Essential Service                Health               Housing
#
#   5th Most Common Venue
# 0               Housing
# 1                Health
# 2               Housing
# 3               Housing
# 4               Liesure

# %%
# create map
map_clusters = folium.Map(location=[visual_center[0], visual_center[1]], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(result_data['Latitude'], result_data['Longitude'], result_data['Address'], result_data['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_a18cd2538aea493a91066d02c757f9bc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a18cd2538aea493a91066d02c757f9bc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a18cd2538aea493a91066d02c757f9bc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_a18cd2538aea493a91066d02c757f9bc%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B14.4785963%2C121.0453278%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
c1 = result_data.loc[result_data['Cluster Labels'] == 0, result_data.columns[[1] + list(range(5, result_data.shape[1]))]]
c2 = result_data.loc[result_data['Cluster Labels'] == 1, result_data.columns[[1] + list(range(5, result_data.shape[1]))]]
c3 = result_data.loc[result_data['Cluster Labels'] == 2, result_data.columns[[1] + list(range(5, result_data.shape[1]))]]
c4 = result_data.loc[result_data['Cluster Labels'] == 3, result_data.columns[[1] + list(range(5, result_data.shape[1]))]]
c5 = result_data.loc[result_data['Cluster Labels'] == 4, result_data.columns[[1] + list(range(5, result_data.shape[1]))]]

# %%
def counter(data):
    
    dict = {}
    categories = ["Food", "Retail", "Liesure", "Essential Service", "Health", "Housing"]
    for category in categories:
        dict[category] = data[data == category].count()
    return dict


# c1["2nd Most Common Venue"][c1["2nd Most Common Venue"] == "Retail"].count()

# %%
def count(venue_type):
    table=[]   
    for cluster, text in zip([c1,c2,c3,c4,c5], ["C1", "C2", "C3", "C4", "C5"]):   
        categories = ["Food", "Retail", "Liesure", "Essential Service", "Health", "Housing"]
        for category in categories:
            my_dict = {}
            my_dict["Cluster"] = text
            my_dict["Category"] = category
            my_dict["Count"] = cluster[venue_type][cluster[venue_type] == category].count()
            table.append(my_dict)
    df_table = pd.DataFrame(table)
    return df_table

def plot(data_table):
    g = sns.catplot(
    data=data_table, kind="bar",
    x="Cluster", y="Count", hue="Category",
    ci="sd", palette="bright", alpha=.6, height=6, aspect=2
    )
    g.despine(left=True)
    g.set_axis_labels("", "Count")
    g.legend.set_title("")
    return g

# %%
df_table = count(venue_type = "1st Most Common Venue")

k = plot(df_table)
k.savefig("Output.tiff")

# %%
result_data.loc[result_data['Cluster Labels'] == 4, result_data.columns[[0] + [-5,-4,-3,-2,-1]]]
# Out:
#                      Address 1st Most Common Venue 2nd Most Common Venue  \
# 0   Bagumbayan,  Taguig City               Liesure                Health
# 14      Tanyag,  Taguig City               Liesure     Essential Service
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 0      Essential Service                  Food               Housing
# 14                  Food                Health               Housing
